# %%
import os
import logging
import pickle
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from gensim.models import Phrases, LdaModel
from gensim.corpora import Dictionary
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
from pprint import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

class TopicModeler:
    def __init__(self, input_path):
        self.input_path = input_path
        self.docs = []
        self.filtered_docs = []
        self.dictionary = None
        self.corpus = None
        self.model = None
        self.coherence_scores = []
        self.perplexity_scores = []
        self.tokenizer = RegexpTokenizer(r'\w+')
        self.lemmatizer = WordNetLemmatizer()
        logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

    def load_documents(self):
        for filename in os.listdir(self.input_path):
            file_path = os.path.join(self.input_path, filename)
            if os.path.isfile(file_path) and filename.endswith('.txt'):
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read().strip()
                    if isinstance(content, str):
                        self.docs.append(content)
        print(f"Loaded {len(self.docs)} documents")
        if self.docs:
            print(f"Sample document: {self.docs[0][:100]}...")

    def preprocess_documents(self):
        self.docs = [[token.lower() for token in self.tokenizer.tokenize(doc)] for doc in self.docs if isinstance(doc, str)]
        self.docs = [[token for token in doc if not token.isnumeric() and len(token) > 1] for doc in self.docs]
        stop_words = set(stopwords.words('english'))
        self.docs = [[word for word in doc if word not in stop_words] for doc in self.docs]
        self.docs = [[self.lemmatizer.lemmatize(token) for token in doc] for doc in self.docs]
        print(f"After preprocessing: {len(self.docs)} documents")
        if self.docs:
            print(f"Sample preprocessed document: {self.docs[0][:10]}...")

    def add_bigrams(self):
        bigram = Phrases(self.docs, min_count=5, threshold=100)
        for idx in range(len(self.docs)):
            for token in bigram[self.docs[idx]]:
                if '_' in token:
                    self.docs[idx].append(token)
        print(f"Added bigrams. Sample document: {self.docs[0][:15]}...")

    def filter_with_tfidf(self, top_n=200, bottom_n=50):
        texts = [' '.join(doc) for doc in self.docs]
        tfidf_vectorizer = TfidfVectorizer()
        tfidf_matrix = tfidf_vectorizer.fit_transform(texts)
        feature_names = tfidf_vectorizer.get_feature_names_out()
        mean_tfidf_scores = np.asarray(tfidf_matrix.mean(axis=0)).flatten()
        
        top_indices = mean_tfidf_scores.argsort()[-top_n:]
        bottom_indices = mean_tfidf_scores.argsort()[:bottom_n]
        
        words_to_remove = set(feature_names[i] for i in np.concatenate([top_indices, bottom_indices]))

        self.filtered_docs = [[word for word in doc if word not in words_to_remove] for doc in self.docs]
        print(f"Filtered documents using TF-IDF. Sample filtered document: {self.filtered_docs[0][:10]}...")

    def create_dictionary_and_corpus(self):
        self.dictionary = Dictionary(self.filtered_docs)
        original_size = len(self.dictionary)
        self.dictionary.filter_extremes(no_below=2, no_above=0.9)
        self.corpus = [self.dictionary.doc2bow(doc) for doc in self.filtered_docs]
        print(f"Dictionary size: {len(self.dictionary)} (reduced from {original_size})")
        print(f"Corpus size: {len(self.corpus)}")
        if self.corpus:
            print(f"Sample corpus entry: {self.corpus[0][:10]}")

    def train_lda_model(self, num_topics=6, chunksize=2000, passes=20, iterations=400, alpha='auto', eta='auto'):
        if not self.corpus or not self.dictionary:
            raise ValueError("Corpus or dictionary is empty. Check your preprocessing steps.")
        
        print(f"Training LDA model with num_topics={num_topics}, chunksize={chunksize}, passes={passes}, iterations={iterations}, alpha={alpha}, eta={eta}")
        
        self.model = LdaModel(
            corpus=self.corpus,
            id2word=self.dictionary,
            chunksize=chunksize,
            alpha=alpha,
            eta=eta,
            iterations=iterations,
            num_topics=num_topics,
            passes=passes,
            eval_every=None,
            random_state=42
        )
        print("LDA model trained successfully")

    def print_model_info(self):
        print('Number of unique tokens: %d' % len(self.dictionary))
        print('Number of documents: %d' % len(self.corpus))
        top_topics = self.model.top_topics(self.corpus)
        avg_topic_coherence = sum([t[1] for t in top_topics]) / self.model.num_topics
        print('Average topic coherence: %.4f.' % avg_topic_coherence)
        print("\nTop topics:")
        pprint(self.model.print_topics())
        print('\nPerplexity: ', self.model.log_perplexity(self.corpus))
        perplexity=self.model.log_perplexity(self.corpus)
        coherence_model_lda = CoherenceModel(model=self.model, texts=self.filtered_docs, dictionary=self.dictionary, coherence='c_v')
        coherence_lda = coherence_model_lda.get_coherence()
        print('\nCoherence Score: ', coherence_lda)
        return coherence_lda,perplexity

    def visualize_topics(self):
        vis = pyLDAvis.gensim.prepare(self.model, self.corpus, self.dictionary)
        return vis

    def analyze_documents(self):
        for i, doc in enumerate(self.filtered_docs[:5]):
            bow = self.dictionary.doc2bow(doc)
            doc_topics = self.model.get_document_topics(bow)
            print(f"\nDocument {i} topics:")
            pprint(doc_topics)
            best_topic = max(doc_topics, key=lambda x: x[1])
            print(f"Best topic: {best_topic[0]}")
            print(f"Top words in this topic:")
            pprint(self.model.show_topic(best_topic[0]))
            print(f"Original document: {' '.join(doc[:30])}...")
            print()

    def save_model(self, file_path):
        if self.model is None:
            raise ValueError("No model has been trained yet.")
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        self.model.save(file_path)
        print(f"Model saved to {file_path}")

    def load_model(self, file_path):
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"No model file found at {file_path}")
        self.model = LdaModel.load(file_path)
        print(f"Model loaded from {file_path}")

    def save_dictionary_and_corpus(self, dict_path, corpus_path):
        if self.dictionary is None or self.corpus is None:
            raise ValueError("Dictionary and corpus have not been created yet.")
        os.makedirs(os.path.dirname(dict_path), exist_ok=True)
        os.makedirs(os.path.dirname(corpus_path), exist_ok=True)
        self.dictionary.save(dict_path)
        with open(corpus_path, 'wb') as f:
            pickle.dump(self.corpus, f)
        print(f"Dictionary saved to {dict_path}")
        print(f"Corpus saved to {corpus_path}")

    def load_dictionary_and_corpus(self, dict_path, corpus_path):
        if not os.path.exists(dict_path) or not os.path.exists(corpus_path):
            raise FileNotFoundError(f"Dictionary or corpus file not found.")
        self.dictionary = Dictionary.load(dict_path)
        with open(corpus_path, 'rb') as f:
            self.corpus = pickle.load(f)
        print(f"Dictionary loaded from {dict_path}")
        print(f"Corpus loaded from {corpus_path}")

    def plot_scores(self, iteration):
        num_topics = [x[0] for x in self.coherence_scores]
        coherences = [x[1] for x in self.coherence_scores]
        perplexities = [x[1] for x in self.perplexity_scores]  # Extract perplexities

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1)
        plt.plot(num_topics, coherences, marker='o', label='Coherence')
        plt.xlabel('Number of Topics')
        plt.ylabel('Coherence Score')
        plt.title('Coherence Score by Number of Topics')
        plt.grid(True)
        plt.xticks(num_topics)
        plt.ylim(0, max(coherences) * 1.1)
        
        plt.subplot(1, 2, 2)
        plt.plot(num_topics, perplexities, marker='o', color='r', label='Perplexity')
        plt.xlabel('Number of Topics')
        plt.ylabel('Perplexity')
        plt.title('Perplexity by Number of Topics')
        plt.grid(True)
        plt.xticks(num_topics)

        plt.tight_layout()
        plt.savefig(f'coherence_perplexity_scores_iteration_{iteration}.png')
        plt.close()

    def get_word_frequencies(self):
        topics = self.model.get_topics()
        word_frequencies = np.sum(topics, axis=0)
        word_frequencies /= self.model.num_topics
        return {self.dictionary[i]: freq for i, freq in enumerate(word_frequencies)}

    def get_low_frequency_words(self, threshold=0.01):
        word_frequencies = self.get_word_frequencies()
        return {word: freq for word, freq in word_frequencies.items() if freq < threshold}

    def get_high_frequency_words(self, threshold=0.00016):
        word_frequencies = self.get_word_frequencies()
        high_freq_words = {word: freq for word, freq in word_frequencies.items() if freq > threshold}
        
        if not high_freq_words:
            print(f"No words found with a frequency higher than the threshold of {threshold}.")
        
        return high_freq_words


    def save_frequency_words(self, low_freq_file, high_freq_file, low_threshold=0.01, high_threshold=0.1):
        low_freq_words = self.get_low_frequency_words(low_threshold)
        high_freq_words = self.get_high_frequency_words(high_threshold)

        df_low = pd.DataFrame(list(low_freq_words.items()), columns=['Word', 'Frequency'])
        df_low = df_low.sort_values('Frequency', ascending=True)
        df_low.to_csv(low_freq_file, index=False)
        print(f"Low frequency words saved to {low_freq_file}")

        df_high = pd.DataFrame(list(high_freq_words.items()), columns=['Word', 'Frequency'])
        df_high = df_high.sort_values('Frequency', ascending=False)
        df_high.to_csv(high_freq_file, index=False)
        print(f"High frequency words saved to {high_freq_file}")

    def run_with_params(self, num_topics, chunksize, passes, iterations):
        try:
            self.load_documents()
            self.preprocess_documents()
            self.add_bigrams()
            self.filter_with_tfidf(top_n=200, bottom_n=50)
            self.create_dictionary_and_corpus()
            self.train_lda_model(num_topics=num_topics, chunksize=chunksize, passes=passes, iterations=iterations)
            model_dir = f"lda_models/topics_{num_topics}_passes_{passes}_iterations_{iterations}"
            self.save_model(os.path.join(model_dir, 'trained_model'))
            self.save_dictionary_and_corpus(os.path.join(model_dir, 'dictionary'), os.path.join(model_dir, 'corpus'))
            coherence_lda, perplexity = self.print_model_info()  # Capture perplexity
            self.coherence_scores.append((num_topics, coherence_lda))
            self.perplexity_scores.append((num_topics, perplexity))  # Store perplexity
            
            # Plot and save coherence and perplexity score after each run
            self.plot_scores(len(self.coherence_scores))
            
            vis = self.visualize_topics()
            pyLDAvis.save_html(vis, os.path.join(model_dir, 'lda_visualization.html'))
            self.analyze_documents()
            
            return vis
        except Exception as e:
            print(f"An error occurred: {str(e)}")
            raise

if __name__ == "__main__":
    modeler = TopicModeler('txt')

    param_combinations = [
        (15, 2000, 10, 200),
        (30, 2000, 10, 400),
        (45, 2000, 20, 200),
        (60, 2000, 20, 400),
        (75, 2000, 20, 400),
        (90, 2000, 20, 400)
    ]

    csv_folder = 'csv_output'
    os.makedirs(csv_folder, exist_ok=True)

    for num_topics, chunksize, passes, iterations in param_combinations:
        print(f"\nRunning model with parameters: num_topics={num_topics}, chunksize={chunksize}, passes={passes}, iterations={iterations}")
        modeler.run_with_params(num_topics, chunksize, passes, iterations)
    
    modeler.save_frequency_words(
        os.path.join(csv_folder, 'low_freq_words.csv'),
        os.path.join(csv_folder, 'high_freq_words.csv'),
        low_threshold=0.01,
    high_threshold=0.00016
    )
# Out:
# Running model with parameters: num_topics=15, chunksize=2000, passes=10, iterations=200
# Loaded 440 documents
# Sample document: Pricing for interconnection related to the provision of number portability, as referred to in Articl...
# 2024-08-06 18:19:24,839 : INFO : collecting all words and their counts
# 2024-08-06 18:19:24,840 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-08-06 18:19:24,862 : INFO : collected 23445 token types (unigram + bigrams) from a corpus of 44718 words and 440 sentences
# 2024-08-06 18:19:24,862 : INFO : merged Phrases<23445 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# 2024-08-06 18:19:24,863 : INFO : Phrases lifecycle event {'msg': 'built Phrases<23445 vocab, min_count=5, threshold=100, max_vocab_size=40000000> in 0.02s', 'datetime': '2024-08-06T18:19:24.863347', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# 2024-08-06 18:19:24,938 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2024-08-06 18:19:24,948 : INFO : built Dictionary<3416 unique tokens: ['abstract', 'adoption', 'advance', 'appeal', 'body']...> from 440 documents (total 19243 corpus positions)
# 2024-08-06 18:19:24,948 : INFO : Dictionary lifecycle event {'msg': "built Dictionary<3416 unique tokens: ['abstract', 'adoption', 'advance', 'appeal', 'body']...> from 440 documents (total 19243 corpus positions)", 'datetime': '2024-08-06T18:19:24.948877', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# 2024-08-06 18:19:24,950 : INFO : discarding 1581 tokens: [('abstract', 1), ('confidential', 1), ('confidentiality', 1), ('dissuaded', 1), ('donor', 1), ('ported', 1), ('porting', 1), ('reaching', 1), ('becomes', 1), ('referral', 1)]...
# 2024-08-06 18:19:24,950 : INFO : keeping 1835 tokens which were in no less than 2 and no more than 396 (=90.0%) documents
# 2024-08-06 18:19:24,951 : INFO : resulting dictionary: Dictionary<1835 unique tokens: ['adoption', 'advance', 'appeal', 'body', 'calculating']...>
# 2024-08-06 18:19:24,959 : INFO : using autotuned alpha, starting with [0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667]
# 2024-08-06 18:19:24,961 : INFO : using serial LDA version on this node
# 2024-08-06 18:19:24,963 : INFO : running online (multi-pass) LDA training, 15 topics, 10 passes over the supplied corpus of 440 documents, updating model once every 440 documents, evaluating perplexity every 0 documents, iterating 200x with a convergence threshold of 0.001000
# 2024-08-06 18:19:24,964 : INFO : PROGRESS: pass 0, at document #440/440
# After preprocessing: 440 documents
# Sample preprocessed document: ['pricing', 'interconnection', 'related', 'provision', 'number', 'portability', 'referred', 'article', 'directive', 'ec']...
# Added bigrams. Sample document: ['pricing', 'interconnection', 'related', 'provision', 'number', 'portability', 'referred', 'article', 'directive', 'ec', 'european', 'parliament', 'council', 'march', 'universal']...
# Filtered documents using TF-IDF. Sample filtered document: ['pricing', 'interconnection', 'related', 'number', 'portability', 'concern', 'traffic', 'number', 'ported', 'set']...
# Dictionary size: 1835 (reduced from 3416)
# Corpus size: 440
# Sample corpus entry: [(0, 1), (1, 1), (2, 3), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1), (9, 1)]
# Training LDA model with num_topics=15, chunksize=2000, passes=10, iterations=200, alpha=auto, eta=auto
# 2024-08-06 18:19:25,119 : INFO : optimized alpha [0.05601553, 0.055268753, 0.0526802, 0.054346085, 0.054080088, 0.053848427, 0.053853672, 0.051989175, 0.05495826, 0.056449115, 0.05256947, 0.0520408, 0.05585058, 0.054048866, 0.05386136]
# 2024-08-06 18:19:25,121 : INFO : topic #7 (0.052): 0.012*"device" + 0.009*"charge" + 0.008*"equipment" + 0.008*"licence" + 0.007*"paid" + 0.006*"authorisation" + 0.006*"vehicle" + 0.006*"damage" + 0.006*"year" + 0.005*"however"
# 2024-08-06 18:19:25,121 : INFO : topic #11 (0.052): 0.012*"operator" + 0.010*"damage" + 0.010*"wine" + 0.008*"notification" + 0.007*"established" + 0.007*"accommodation" + 0.007*"description" + 0.007*"used" + 0.006*"property" + 0.006*"third"
# 2024-08-06 18:19:25,122 : INFO : topic #12 (0.056): 0.008*"read_conjunction" + 0.008*"conjunction" + 0.007*"set" + 0.007*"take" + 0.007*"required" + 0.006*"water" + 0.006*"conformity" + 0.005*"place" + 0.005*"packaging" + 0.005*"second"
# 2024-08-06 18:19:25,122 : INFO : topic #0 (0.056): 0.009*"call" + 0.008*"number" + 0.007*"emergency" + 0.007*"telephone" + 0.006*"make" + 0.006*"property" + 0.005*"provide" + 0.005*"caller" + 0.005*"single" + 0.005*"shop"
# 2024-08-06 18:19:25,123 : INFO : topic #9 (0.056): 0.008*"conjunction" + 0.008*"consequence" + 0.008*"read_conjunction" + 0.007*"provider" + 0.006*"country" + 0.006*"operator" + 0.006*"required" + 0.005*"vehicle" + 0.005*"society" + 0.005*"information_society"
# 2024-08-06 18:19:25,123 : INFO : topic diff=9.599198, rho=1.000000
# 2024-08-06 18:19:25,124 : INFO : PROGRESS: pass 1, at document #440/440
# 2024-08-06 18:19:25,168 : INFO : optimized alpha [0.05159938, 0.051309396, 0.047186065, 0.050058223, 0.04974774, 0.049475763, 0.04889743, 0.046821546, 0.050092492, 0.052266784, 0.04750884, 0.047016136, 0.05137962, 0.049848326, 0.049627513]
# 2024-08-06 18:19:25,170 : INFO : topic #7 (0.047): 0.014*"device" + 0.008*"charge" + 0.008*"vehicle" + 0.007*"paid" + 0.007*"equipment" + 0.007*"licence" + 0.007*"year" + 0.007*"damage" + 0.006*"authorisation" + 0.006*"advertiser"
# 2024-08-06 18:19:25,170 : INFO : topic #11 (0.047): 0.012*"operator" + 0.011*"damage" + 0.010*"wine" + 0.008*"notification" + 0.007*"established" + 0.007*"economic" + 0.007*"accommodation" + 0.007*"description" + 0.007*"used" + 0.006*"property"
# 2024-08-06 18:19:25,171 : INFO : topic #12 (0.051): 0.009*"read_conjunction" + 0.009*"conjunction" + 0.008*"set" + 0.007*"take" + 0.007*"required" + 0.006*"water" + 0.006*"packaging" + 0.006*"conformity" + 0.006*"place" + 0.006*"safety"
# 2024-08-06 18:19:25,171 : INFO : topic #0 (0.052): 0.011*"call" + 0.009*"number" + 0.009*"emergency" + 0.007*"telephone" + 0.006*"make" + 0.006*"caller" + 0.006*"single" + 0.005*"property" + 0.005*"lender" + 0.005*"available"
# 2024-08-06 18:19:25,172 : INFO : topic #9 (0.052): 0.009*"consequence" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"operator" + 0.007*"provider" + 0.007*"society" + 0.007*"information_society" + 0.006*"country" + 0.005*"required" + 0.005*"finding"
# 2024-08-06 18:19:25,172 : INFO : topic diff=0.183435, rho=0.577350
# 2024-08-06 18:19:25,174 : INFO : PROGRESS: pass 2, at document #440/440
# 2024-08-06 18:19:25,210 : INFO : optimized alpha [0.04827008, 0.048544377, 0.04344035, 0.046967857, 0.046686623, 0.046397198, 0.045465916, 0.043383498, 0.046639495, 0.04910189, 0.04383947, 0.043491866, 0.048155025, 0.046746124, 0.04651144]
# 2024-08-06 18:19:25,211 : INFO : topic #2 (0.043): 0.009*"ensure" + 0.008*"procedure" + 0.008*"registration" + 0.008*"framework" + 0.007*"january" + 0.006*"regulatory" + 0.006*"domestic" + 0.006*"objective" + 0.006*"access" + 0.006*"precludes"
# 2024-08-06 18:19:25,212 : INFO : topic #7 (0.043): 0.016*"device" + 0.011*"vehicle" + 0.008*"charge" + 0.007*"year" + 0.007*"paid" + 0.007*"damage" + 0.007*"equipment" + 0.007*"licence" + 0.006*"defeat_device" + 0.006*"level"
# 2024-08-06 18:19:25,212 : INFO : topic #0 (0.048): 0.012*"call" + 0.010*"number" + 0.010*"emergency" + 0.008*"telephone" + 0.006*"make" + 0.006*"caller" + 0.006*"single" + 0.006*"lender" + 0.006*"available" + 0.005*"retail"
# 2024-08-06 18:19:25,212 : INFO : topic #1 (0.049): 0.008*"protected_designation" + 0.008*"trade_mark" + 0.008*"agricultural" + 0.007*"fact" + 0.007*"grand" + 0.007*"grand_duchy" + 0.007*"luxembourg" + 0.007*"duchy" + 0.006*"television" + 0.006*"registration"
# 2024-08-06 18:19:25,213 : INFO : topic #9 (0.049): 0.009*"consequence" + 0.008*"society" + 0.008*"information_society" + 0.008*"operator" + 0.007*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country" + 0.006*"commerce" + 0.006*"electronic_commerce"
# 2024-08-06 18:19:25,213 : INFO : topic diff=0.176749, rho=0.500000
# 2024-08-06 18:19:25,215 : INFO : PROGRESS: pass 3, at document #440/440
# 2024-08-06 18:19:25,251 : INFO : optimized alpha [0.045767296, 0.04639098, 0.040629968, 0.044589687, 0.044377077, 0.043981224, 0.042909827, 0.04077949, 0.043804333, 0.046612978, 0.040931165, 0.040780462, 0.045733675, 0.04431469, 0.04417443]
# 2024-08-06 18:19:25,253 : INFO : topic #2 (0.041): 0.009*"ensure" + 0.008*"procedure" + 0.008*"framework" + 0.008*"registration" + 0.008*"january" + 0.007*"regulatory" + 0.006*"domestic" + 0.006*"defect" + 0.006*"objective" + 0.006*"access"
# 2024-08-06 18:19:25,253 : INFO : topic #11 (0.041): 0.012*"damage" + 0.012*"operator" + 0.009*"wine" + 0.007*"notification" + 0.007*"established" + 0.007*"economic" + 0.006*"property" + 0.006*"accommodation" + 0.006*"description" + 0.006*"used"
# 2024-08-06 18:19:25,253 : INFO : topic #0 (0.046): 0.012*"call" + 0.010*"emergency" + 0.010*"number" + 0.008*"telephone" + 0.007*"single" + 0.007*"make" + 0.006*"caller" + 0.006*"lender" + 0.006*"available" + 0.006*"retail"
# 2024-08-06 18:19:25,254 : INFO : topic #1 (0.046): 0.009*"protected_designation" + 0.008*"agricultural" + 0.008*"grand" + 0.008*"trade_mark" + 0.008*"fact" + 0.007*"grand_duchy" + 0.007*"luxembourg" + 0.007*"duchy" + 0.007*"registration" + 0.007*"television"
# 2024-08-06 18:19:25,254 : INFO : topic #9 (0.047): 0.010*"consequence" + 0.009*"society" + 0.009*"information_society" + 0.008*"operator" + 0.008*"commerce" + 0.008*"electronic_commerce" + 0.007*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,254 : INFO : topic diff=0.159644, rho=0.447214
# 2024-08-06 18:19:25,256 : INFO : PROGRESS: pass 4, at document #440/440
# 2024-08-06 18:19:25,292 : INFO : optimized alpha [0.043674488, 0.044555906, 0.03837609, 0.042681716, 0.042476803, 0.042005002, 0.040918425, 0.03871466, 0.041565586, 0.044573124, 0.038722016, 0.03863574, 0.043793112, 0.04228589, 0.042256337]
# 2024-08-06 18:19:25,295 : INFO : topic #2 (0.038): 0.009*"ensure" + 0.009*"framework" + 0.008*"procedure" + 0.008*"january" + 0.008*"registration" + 0.007*"regulatory" + 0.007*"domestic" + 0.007*"defect" + 0.006*"access" + 0.006*"precludes"
# 2024-08-06 18:19:25,295 : INFO : topic #11 (0.039): 0.013*"damage" + 0.012*"operator" + 0.009*"wine" + 0.007*"notification" + 0.007*"economic" + 0.007*"established" + 0.006*"property" + 0.006*"accommodation" + 0.006*"description" + 0.006*"used"
# 2024-08-06 18:19:25,296 : INFO : topic #12 (0.044): 0.011*"read_conjunction" + 0.011*"conjunction" + 0.009*"set" + 0.008*"take" + 0.008*"required" + 0.007*"safety" + 0.007*"packaging" + 0.007*"food_safety" + 0.007*"water" + 0.006*"emergency"
# 2024-08-06 18:19:25,296 : INFO : topic #9 (0.045): 0.010*"consequence" + 0.009*"society" + 0.009*"information_society" + 0.009*"commerce" + 0.009*"electronic_commerce" + 0.008*"operator" + 0.007*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,296 : INFO : topic #1 (0.045): 0.009*"protected_designation" + 0.009*"agricultural" + 0.008*"grand" + 0.008*"registration" + 0.008*"trade_mark" + 0.008*"grand_duchy" + 0.008*"luxembourg" + 0.008*"duchy" + 0.008*"fact" + 0.007*"designation_origin"
# 2024-08-06 18:19:25,297 : INFO : topic diff=0.141121, rho=0.408248
# 2024-08-06 18:19:25,303 : INFO : PROGRESS: pass 5, at document #440/440
# 2024-08-06 18:19:25,352 : INFO : optimized alpha [0.04195486, 0.043077108, 0.03654391, 0.04107074, 0.040984288, 0.04045875, 0.03924794, 0.036990486, 0.039704397, 0.04285397, 0.036887888, 0.036851384, 0.042153727, 0.0405827, 0.04063773]
# 2024-08-06 18:19:25,354 : INFO : topic #2 (0.037): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"january" + 0.008*"registration" + 0.008*"regulatory" + 0.007*"domestic" + 0.007*"defect" + 0.006*"access" + 0.006*"precludes"
# 2024-08-06 18:19:25,354 : INFO : topic #11 (0.037): 0.013*"damage" + 0.012*"operator" + 0.009*"wine" + 0.007*"economic" + 0.007*"notification" + 0.007*"established" + 0.006*"property" + 0.006*"accommodation" + 0.006*"description" + 0.006*"used"
# 2024-08-06 18:19:25,355 : INFO : topic #12 (0.042): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"set" + 0.008*"safety" + 0.008*"take" + 0.008*"required" + 0.007*"food_safety" + 0.007*"packaging" + 0.007*"laying" + 0.007*"water"
# 2024-08-06 18:19:25,355 : INFO : topic #9 (0.043): 0.010*"consequence" + 0.010*"society" + 0.010*"information_society" + 0.009*"commerce" + 0.009*"electronic_commerce" + 0.009*"operator" + 0.008*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,355 : INFO : topic #1 (0.043): 0.009*"protected_designation" + 0.009*"agricultural" + 0.009*"registration" + 0.009*"grand" + 0.008*"grand_duchy" + 0.008*"luxembourg" + 0.008*"duchy" + 0.008*"trade_mark" + 0.008*"fact" + 0.008*"designation_origin"
# 2024-08-06 18:19:25,356 : INFO : topic diff=0.123866, rho=0.377964
# 2024-08-06 18:19:25,357 : INFO : PROGRESS: pass 6, at document #440/440
# 2024-08-06 18:19:25,393 : INFO : optimized alpha [0.040476214, 0.041827243, 0.034986947, 0.039680865, 0.039691117, 0.03912268, 0.037844867, 0.03551684, 0.038119197, 0.04137506, 0.03532792, 0.035330933, 0.040738847, 0.03912058, 0.03924223]
# 2024-08-06 18:19:25,395 : INFO : topic #2 (0.035): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"january" + 0.008*"regulatory" + 0.008*"registration" + 0.007*"domestic" + 0.007*"defect" + 0.006*"drink" + 0.006*"spirit"
# 2024-08-06 18:19:25,395 : INFO : topic #10 (0.035): 0.010*"3a" + 0.009*"comparative" + 0.008*"set" + 0.007*"mortgage" + 0.007*"advertiser" + 0.007*"competitor" + 0.007*"available" + 0.007*"misleading" + 0.007*"comparison" + 0.007*"offer"
# 2024-08-06 18:19:25,396 : INFO : topic #12 (0.041): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"set" + 0.009*"safety" + 0.008*"take" + 0.008*"required" + 0.008*"food_safety" + 0.007*"laying" + 0.007*"packaging" + 0.007*"water"
# 2024-08-06 18:19:25,396 : INFO : topic #9 (0.041): 0.010*"consequence" + 0.010*"society" + 0.010*"information_society" + 0.010*"commerce" + 0.010*"electronic_commerce" + 0.009*"operator" + 0.008*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,397 : INFO : topic #1 (0.042): 0.009*"protected_designation" + 0.009*"registration" + 0.009*"agricultural" + 0.009*"grand" + 0.008*"grand_duchy" + 0.008*"luxembourg" + 0.008*"duchy" + 0.008*"designation_origin" + 0.008*"trade_mark" + 0.008*"fact"
# 2024-08-06 18:19:25,398 : INFO : topic diff=0.107275, rho=0.353553
# 2024-08-06 18:19:25,400 : INFO : PROGRESS: pass 7, at document #440/440
# 2024-08-06 18:19:25,437 : INFO : optimized alpha [0.039151665, 0.040722705, 0.03364022, 0.038526863, 0.03858422, 0.0379818, 0.03661979, 0.03423628, 0.0367457, 0.040115494, 0.034006525, 0.03404064, 0.039499383, 0.037876546, 0.03802085]
# 2024-08-06 18:19:25,439 : INFO : topic #2 (0.034): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"regulatory" + 0.008*"january" + 0.007*"registration" + 0.007*"domestic" + 0.007*"defect" + 0.007*"drink" + 0.007*"spirit"
# 2024-08-06 18:19:25,439 : INFO : topic #10 (0.034): 0.011*"3a" + 0.009*"comparative" + 0.008*"set" + 0.008*"advertiser" + 0.007*"mortgage" + 0.007*"competitor" + 0.007*"available" + 0.007*"misleading" + 0.007*"comparison" + 0.007*"offer"
# 2024-08-06 18:19:25,439 : INFO : topic #12 (0.039): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"safety" + 0.009*"set" + 0.008*"take" + 0.008*"required" + 0.008*"food_safety" + 0.007*"laying" + 0.007*"packaging" + 0.007*"water"
# 2024-08-06 18:19:25,444 : INFO : topic #9 (0.040): 0.010*"consequence" + 0.010*"commerce" + 0.010*"electronic_commerce" + 0.010*"society" + 0.010*"information_society" + 0.009*"operator" + 0.008*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,445 : INFO : topic #1 (0.041): 0.010*"protected_designation" + 0.010*"registration" + 0.009*"agricultural" + 0.009*"grand" + 0.009*"designation_origin" + 0.008*"grand_duchy" + 0.008*"luxembourg" + 0.008*"duchy" + 0.008*"trade_mark" + 0.008*"fact"
# 2024-08-06 18:19:25,445 : INFO : topic diff=0.092718, rho=0.333333
# 2024-08-06 18:19:25,447 : INFO : PROGRESS: pass 8, at document #440/440
# 2024-08-06 18:19:25,484 : INFO : optimized alpha [0.03798211, 0.039735317, 0.03248456, 0.037501268, 0.037597477, 0.03699586, 0.035507236, 0.033134654, 0.03553883, 0.038999498, 0.03287081, 0.03290457, 0.038399708, 0.036859903, 0.03693839]
# 2024-08-06 18:19:25,486 : INFO : topic #2 (0.032): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"regulatory" + 0.008*"january" + 0.007*"registration" + 0.007*"domestic" + 0.007*"defect" + 0.007*"drink" + 0.007*"spirit"
# 2024-08-06 18:19:25,486 : INFO : topic #10 (0.033): 0.011*"3a" + 0.010*"comparative" + 0.008*"advertiser" + 0.008*"set" + 0.007*"mortgage" + 0.007*"misleading" + 0.007*"competitor" + 0.007*"available" + 0.007*"comparison" + 0.007*"offer"
# 2024-08-06 18:19:25,487 : INFO : topic #12 (0.038): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"safety" + 0.009*"set" + 0.008*"food_safety" + 0.008*"take" + 0.008*"required" + 0.008*"laying" + 0.007*"packaging" + 0.007*"water"
# 2024-08-06 18:19:25,487 : INFO : topic #9 (0.039): 0.010*"consequence" + 0.010*"commerce" + 0.010*"electronic_commerce" + 0.010*"society" + 0.010*"information_society" + 0.009*"operator" + 0.008*"provider" + 0.007*"conjunction" + 0.007*"read_conjunction" + 0.007*"country"
# 2024-08-06 18:19:25,488 : INFO : topic #1 (0.040): 0.010*"protected_designation" + 0.010*"registration" + 0.010*"agricultural" + 0.009*"grand" + 0.009*"designation_origin" + 0.009*"grand_duchy" + 0.009*"luxembourg" + 0.009*"duchy" + 0.008*"trade_mark" + 0.008*"fact"
# 2024-08-06 18:19:25,488 : INFO : topic diff=0.080299, rho=0.316228
# 2024-08-06 18:19:25,490 : INFO : PROGRESS: pass 9, at document #440/440
# 2024-08-06 18:19:25,525 : INFO : optimized alpha [0.036937337, 0.038843524, 0.031456888, 0.03660622, 0.03670834, 0.036108237, 0.034513302, 0.032152142, 0.034465596, 0.03799937, 0.031859998, 0.031892564, 0.037440244, 0.0359214, 0.035968482]
# 2024-08-06 18:19:25,527 : INFO : topic #2 (0.031): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"regulatory" + 0.008*"january" + 0.007*"registration" + 0.007*"domestic" + 0.007*"defect" + 0.007*"drink" + 0.007*"spirit"
# 2024-08-06 18:19:25,527 : INFO : topic #10 (0.032): 0.012*"3a" + 0.011*"comparative" + 0.009*"advertiser" + 0.008*"set" + 0.008*"misleading" + 0.007*"mortgage" + 0.007*"competitor" + 0.007*"available" + 0.007*"comparison" + 0.007*"offer"
# 2024-08-06 18:19:25,528 : INFO : topic #12 (0.037): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"safety" + 0.009*"set" + 0.008*"food_safety" + 0.008*"take" + 0.008*"required" + 0.008*"laying" + 0.007*"packaging" + 0.007*"water"
# 2024-08-06 18:19:25,528 : INFO : topic #9 (0.038): 0.010*"consequence" + 0.010*"commerce" + 0.010*"electronic_commerce" + 0.010*"society" + 0.010*"information_society" + 0.009*"operator" + 0.008*"provider" + 0.007*"country" + 0.007*"conjunction" + 0.007*"read_conjunction"
# 2024-08-06 18:19:25,528 : INFO : topic #1 (0.039): 0.010*"protected_designation" + 0.010*"registration" + 0.010*"agricultural" + 0.009*"designation_origin" + 0.009*"grand" + 0.009*"grand_duchy" + 0.009*"luxembourg" + 0.009*"duchy" + 0.008*"trade_mark" + 0.008*"fact"
# 2024-08-06 18:19:25,529 : INFO : topic diff=0.069224, rho=0.301511
# 2024-08-06 18:19:25,530 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=1835, num_topics=15, decay=0.5, chunksize=2000> in 0.57s', 'datetime': '2024-08-06T18:19:25.530916', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# 2024-08-06 18:19:25,531 : INFO : LdaState lifecycle event {'fname_or_handle': 'lda_models/topics_15_passes_10_iterations_200/trained_model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-08-06T18:19:25.531626', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:19:25,532 : INFO : saved lda_models/topics_15_passes_10_iterations_200/trained_model.state
# 2024-08-06 18:19:25,533 : INFO : LdaModel lifecycle event {'fname_or_handle': 'lda_models/topics_15_passes_10_iterations_200/trained_model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['dispatcher', 'id2word', 'state'], 'datetime': '2024-08-06T18:19:25.533902', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:19:25,534 : INFO : storing np array 'expElogbeta' to lda_models/topics_15_passes_10_iterations_200/trained_model.expElogbeta.npy
# 2024-08-06 18:19:25,535 : INFO : not storing attribute dispatcher
# 2024-08-06 18:19:25,535 : INFO : not storing attribute id2word
# 2024-08-06 18:19:25,535 : INFO : not storing attribute state
# 2024-08-06 18:19:25,536 : INFO : saved lda_models/topics_15_passes_10_iterations_200/trained_model
# 2024-08-06 18:19:25,536 : INFO : Dictionary lifecycle event {'fname_or_handle': 'lda_models/topics_15_passes_10_iterations_200/dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-08-06T18:19:25.536993', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:19:25,537 : INFO : saved lda_models/topics_15_passes_10_iterations_200/dictionary
# 2024-08-06 18:19:25,548 : INFO : topic #0 (0.037): 0.014*"call" + 0.012*"emergency" + 0.011*"number" + 0.008*"single" + 0.007*"telephone" + 0.007*"caller" + 0.007*"lender" + 0.007*"available" + 0.007*"make" + 0.006*"provide"
# 2024-08-06 18:19:25,549 : INFO : topic #1 (0.039): 0.010*"protected_designation" + 0.010*"registration" + 0.010*"agricultural" + 0.009*"designation_origin" + 0.009*"grand" + 0.009*"grand_duchy" + 0.009*"luxembourg" + 0.009*"duchy" + 0.008*"trade_mark" + 0.008*"fact"
# 2024-08-06 18:19:25,549 : INFO : topic #2 (0.031): 0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"regulatory" + 0.008*"january" + 0.007*"registration" + 0.007*"domestic" + 0.007*"defect" + 0.007*"drink" + 0.007*"spirit"
# 2024-08-06 18:19:25,550 : INFO : topic #3 (0.037): 0.017*"le" + 0.015*"et" + 0.012*"la" + 0.011*"en" + 0.009*"mortgage" + 0.009*"take" + 0.009*"assurance" + 0.008*"taken" + 0.008*"taking" + 0.008*"transactional_decision"
# 2024-08-06 18:19:25,551 : INFO : topic #4 (0.037): 0.012*"marketed" + 0.012*"ingredient" + 0.011*"germany" + 0.010*"federal" + 0.009*"federal_republic" + 0.009*"labelling_presentation" + 0.007*"lack" + 0.007*"marketing" + 0.007*"conformity" + 0.007*"charge"
# 2024-08-06 18:19:25,552 : INFO : topic #5 (0.036): 0.031*"currency" + 0.024*"foreign" + 0.021*"exchange" + 0.014*"spain" + 0.012*"kingdom_spain" + 0.012*"risk" + 0.011*"financial" + 0.011*"foreign_currency" + 0.011*"intelligible" + 0.010*"provide"
# 2024-08-06 18:19:25,552 : INFO : topic #6 (0.035): 0.034*"trade_mark" + 0.018*"proprietor" + 0.011*"premise" + 0.009*"unfairness" + 0.009*"away" + 0.008*"third" + 0.008*"reputation" + 0.007*"negotiated" + 0.007*"business_premise" + 0.007*"negotiated_away"
# 2024-08-06 18:19:25,553 : INFO : topic #7 (0.032): 0.018*"device" + 0.017*"vehicle" + 0.011*"advertisement" + 0.009*"year" + 0.009*"belgium" + 0.009*"kingdom_belgium" + 0.008*"defeat_device" + 0.008*"defeat" + 0.008*"level" + 0.008*"advertiser"
# 2024-08-06 18:19:25,553 : INFO : topic #8 (0.034): 0.015*"directory" + 0.015*"data" + 0.011*"property" + 0.011*"subscriber" + 0.010*"provider" + 0.009*"telephone" + 0.008*"dispute" + 0.008*"territory" + 0.008*"procedure" + 0.007*"number"
# 2024-08-06 18:19:25,554 : INFO : topic #9 (0.038): 0.010*"consequence" + 0.010*"commerce" + 0.010*"electronic_commerce" + 0.010*"society" + 0.010*"information_society" + 0.009*"operator" + 0.008*"provider" + 0.007*"country" + 0.007*"conjunction" + 0.007*"read_conjunction"
# 2024-08-06 18:19:25,554 : INFO : topic #10 (0.032): 0.012*"3a" + 0.011*"comparative" + 0.009*"advertiser" + 0.008*"set" + 0.008*"misleading" + 0.007*"mortgage" + 0.007*"competitor" + 0.007*"available" + 0.007*"comparison" + 0.007*"offer"
# 2024-08-06 18:19:25,554 : INFO : topic #11 (0.032): 0.014*"damage" + 0.012*"operator" + 0.009*"wine" + 0.008*"economic" + 0.007*"notification" + 0.007*"established" + 0.006*"property" + 0.006*"description" + 0.006*"accommodation" + 0.006*"used"
# 2024-08-06 18:19:25,555 : INFO : topic #12 (0.037): 0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"safety" + 0.009*"set" + 0.008*"food_safety" + 0.008*"take" + 0.008*"required" + 0.008*"laying" + 0.007*"packaging" + 0.007*"water"
# 2024-08-06 18:19:25,555 : INFO : topic #13 (0.036): 0.017*"natural" + 0.010*"acting" + 0.009*"natural_person" + 0.009*"profession" + 0.008*"producer" + 0.008*"brought" + 0.008*"manufacturer" + 0.007*"substance" + 0.007*"holiday" + 0.007*"german"
# 2024-08-06 18:19:25,555 : INFO : topic #14 (0.036): 0.014*"reasonably" + 0.012*"informed" + 0.009*"guarantee" + 0.009*"well" + 0.009*"travel" + 0.008*"evocation" + 0.008*"reference" + 0.007*"circumspect" + 0.007*"observant_circumspect" + 0.007*"observant"
# 2024-08-06 18:19:25,615 : INFO : -7.332 per-word bound, 161.1 perplexity estimate based on a held-out corpus of 440 documents with 16915 words
# 2024-08-06 18:19:25,669 : INFO : -7.332 per-word bound, 161.1 perplexity estimate based on a held-out corpus of 440 documents with 16915 words
# 2024-08-06 18:19:25,671 : INFO : using ParallelWordOccurrenceAccumulator<processes=9, batch_size=64> to estimate probabilities from sliding windows
# LDA model trained successfully
# Model saved to lda_models/topics_15_passes_10_iterations_200/trained_model
# Dictionary saved to lda_models/topics_15_passes_10_iterations_200/dictionary
# Corpus saved to lda_models/topics_15_passes_10_iterations_200/corpus
# Number of unique tokens: 1835
# Number of documents: 440
# Average topic coherence: -10.8608.
#
# Top topics:
# [(0,
#   '0.014*"call" + 0.012*"emergency" + 0.011*"number" + 0.008*"single" + '
#   '0.007*"telephone" + 0.007*"caller" + 0.007*"lender" + 0.007*"available" + '
#   '0.007*"make" + 0.006*"provide"'),
#  (1,
#   '0.010*"protected_designation" + 0.010*"registration" + 0.010*"agricultural" '
#   '+ 0.009*"designation_origin" + 0.009*"grand" + 0.009*"grand_duchy" + '
#   '0.009*"luxembourg" + 0.009*"duchy" + 0.008*"trade_mark" + 0.008*"fact"'),
#  (2,
#   '0.009*"framework" + 0.009*"ensure" + 0.008*"procedure" + 0.008*"regulatory" '
#   '+ 0.008*"january" + 0.007*"registration" + 0.007*"domestic" + '
#   '0.007*"defect" + 0.007*"drink" + 0.007*"spirit"'),
#  (3,
#   '0.017*"le" + 0.015*"et" + 0.012*"la" + 0.011*"en" + 0.009*"mortgage" + '
#   '0.009*"take" + 0.009*"assurance" + 0.008*"taken" + 0.008*"taking" + '
#   '0.008*"transactional_decision"'),
#  (4,
#   '0.012*"marketed" + 0.012*"ingredient" + 0.011*"germany" + 0.010*"federal" + '
#   '0.009*"federal_republic" + 0.009*"labelling_presentation" + 0.007*"lack" + '
#   '0.007*"marketing" + 0.007*"conformity" + 0.007*"charge"'),
#  (5,
#   '0.031*"currency" + 0.024*"foreign" + 0.021*"exchange" + 0.014*"spain" + '
#   '0.012*"kingdom_spain" + 0.012*"risk" + 0.011*"financial" + '
#   '0.011*"foreign_currency" + 0.011*"intelligible" + 0.010*"provide"'),
#  (6,
#   '0.034*"trade_mark" + 0.018*"proprietor" + 0.011*"premise" + '
#   '0.009*"unfairness" + 0.009*"away" + 0.008*"third" + 0.008*"reputation" + '
#   '0.007*"negotiated" + 0.007*"business_premise" + 0.007*"negotiated_away"'),
#  (7,
#   '0.018*"device" + 0.017*"vehicle" + 0.011*"advertisement" + 0.009*"year" + '
#   '0.009*"belgium" + 0.009*"kingdom_belgium" + 0.008*"defeat_device" + '
#   '0.008*"defeat" + 0.008*"level" + 0.008*"advertiser"'),
#  (8,
#   '0.015*"directory" + 0.015*"data" + 0.011*"property" + 0.011*"subscriber" + '
#   '0.010*"provider" + 0.009*"telephone" + 0.008*"dispute" + 0.008*"territory" '
#   '+ 0.008*"procedure" + 0.007*"number"'),
#  (9,
#   '0.010*"consequence" + 0.010*"commerce" + 0.010*"electronic_commerce" + '
#   '0.010*"society" + 0.010*"information_society" + 0.009*"operator" + '
#   '0.008*"provider" + 0.007*"country" + 0.007*"conjunction" + '
#   '0.007*"read_conjunction"'),
#  (10,
#   '0.012*"3a" + 0.011*"comparative" + 0.009*"advertiser" + 0.008*"set" + '
#   '0.008*"misleading" + 0.007*"mortgage" + 0.007*"competitor" + '
#   '0.007*"available" + 0.007*"comparison" + 0.007*"offer"'),
#  (11,
#   '0.014*"damage" + 0.012*"operator" + 0.009*"wine" + 0.008*"economic" + '
#   '0.007*"notification" + 0.007*"established" + 0.006*"property" + '
#   '0.006*"description" + 0.006*"accommodation" + 0.006*"used"'),
#  (12,
#   '0.012*"read_conjunction" + 0.012*"conjunction" + 0.009*"safety" + '
#   '0.009*"set" + 0.008*"food_safety" + 0.008*"take" + 0.008*"required" + '
#   '0.008*"laying" + 0.007*"packaging" + 0.007*"water"'),
#  (13,
#   '0.017*"natural" + 0.010*"acting" + 0.009*"natural_person" + '
#   '0.009*"profession" + 0.008*"producer" + 0.008*"brought" + '
#   '0.008*"manufacturer" + 0.007*"substance" + 0.007*"holiday" + '
#   '0.007*"german"'),
#  (14,
#   '0.014*"reasonably" + 0.012*"informed" + 0.009*"guarantee" + 0.009*"well" + '
#   '0.009*"travel" + 0.008*"evocation" + 0.008*"reference" + '
#   '0.007*"circumspect" + 0.007*"observant_circumspect" + 0.007*"observant"')]
#
# Perplexity:  -7.331750923840914
# 2024-08-06 18:19:27,674 : INFO : 9 accumulators retrieved from output queue
# 2024-08-06 18:19:27,708 : INFO : accumulated word occurrence stats for 1774 virtual documents
# Coherence Score:  0.3833122839884157
# 2024-08-06 18:19:29,281 : INFO : collecting all words and their counts
# 2024-08-06 18:19:29,282 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-08-06 18:19:29,304 : INFO : collected 23445 token types (unigram + bigrams) from a corpus of 44718 words and 440 sentences
# 2024-08-06 18:19:29,305 : INFO : merged Phrases<23445 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# 2024-08-06 18:19:29,305 : INFO : Phrases lifecycle event {'msg': 'built Phrases<23445 vocab, min_count=5, threshold=100, max_vocab_size=40000000> in 0.02s', 'datetime': '2024-08-06T18:19:29.305826', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# Document 0 topics:
# [(8, 0.99196386)]
# Best topic: 8
# Top words in this topic:
# [('directory', 0.014993575),
#  ('data', 0.014855327),
#  ('property', 0.010726822),
#  ('subscriber', 0.010717523),
#  ('provider', 0.010100084),
#  ('telephone', 0.008550041),
#  ('dispute', 0.008044642),
#  ('territory', 0.008028072),
#  ('procedure', 0.007948749),
#  ('number', 0.0066399556)]
# Original document: pricing interconnection related number portability concern traffic number ported set incurred mobile telephone operator implement request number porting adoption laying method used calculating fix advance abstract model maximum charged donor...
#
#
# Document 1 topics:
# [(13, 0.9814167)]
# Best topic: 13
# Top words in this topic:
# [('natural', 0.01735919),
#  ('acting', 0.010139426),
#  ('natural_person', 0.009203744),
#  ('profession', 0.009188015),
#  ('producer', 0.0083213225),
#  ('brought', 0.008177817),
#  ('manufacturer', 0.008069699),
#  ('substance', 0.007156122),
#  ('holiday', 0.00696203),
#  ('german', 0.0069040526)]
# Original document: natural becomes scheme implemented company allowing inter alia financial benefit connection purchase natural participating scheme referral company partner natural acting outside profession concept romanian natural_person inter_alia natural_person natural_person...
#
#
# Document 2 topics:
# [(1, 0.99314874)]
# Best topic: 1
# Top words in this topic:
# [('protected_designation', 0.010297086),
#  ('registration', 0.010117807),
#  ('agricultural', 0.009775236),
#  ('designation_origin', 0.009153828),
#  ('grand', 0.009092213),
#  ('grand_duchy', 0.008613104),
#  ('luxembourg', 0.008613101),
#  ('duchy', 0.008613098),
#  ('trade_mark', 0.008047676),
#  ('fact', 0.007946616)]
# Original document: approximate 3a september misleading comparative proprietor registered entitled prevent third sign identical similar comparative advertisement satisfies 3a comparative permitted however required prevent sign identical similar registered met comparative advertisement sign...
#
#
# Document 3 topics:
# [(1, 0.99216217)]
# Best topic: 1
# Top words in this topic:
# [('protected_designation', 0.010297086),
#  ('registration', 0.010117807),
#  ('agricultural', 0.009775236),
#  ('designation_origin', 0.009153828),
#  ('grand', 0.009092213),
#  ('grand_duchy', 0.008613104),
#  ('luxembourg', 0.008613101),
#  ('duchy', 0.008613098),
#  ('trade_mark', 0.008047676),
#  ('fact', 0.007946616)]
# Original document: lay method calculating maximum charged calculation method allows bear proportion exercise activity mean maximum contrary harmonised set maximum upper limit provides payable exceeding upper limit total excluded impose repayment principal...
#
#
# Document 4 topics:
# [(3, 0.74073565), (10, 0.24312381)]
# Best topic: 3
# Top words in this topic:
# [('le', 0.016664056),
#  ('et', 0.015269122),
#  ('la', 0.012068827),
#  ('en', 0.010581445),
#  ('mortgage', 0.008819771),
#  ('take', 0.00874663),
#  ('assurance', 0.008529316),
#  ('taken', 0.008397229),
#  ('taking', 0.0076386877),
#  ('transactional_decision', 0.0075087245)]
# Original document: allows recovery debt based potentially extrajudicial charge immovable property security far make excessively difficult impossible protect conferred determine included outside reflects content mandatory statutory regulatory determine immovable_property excessively_difficult...
#
#
# Running model with parameters: num_topics=30, chunksize=2000, passes=10, iterations=400
# Loaded 880 documents
# Sample document: ['pricing', 'interconnection', 'related', 'provision', 'number', 'portability', 'referred', 'article', 'directive', 'ec', 'european', 'parliament', 'council', 'march', 'universal', 'service', 'user', 'right', 'relating', 'electronic', 'communication', 'network', 'service', 'universal', 'service', 'directive', 'concern', 'traffic', 'cost', 'number', 'ported', 'set', 'cost', 'incurred', 'mobile', 'telephone', 'operator', 'implement', 'request', 'number', 'porting', 'article', 'directive', 'preclude', 'adoption', 'national', 'measure', 'laying', 'specific', 'method', 'used', 'calculating', 'cost', 'fix', 'advance', 'basis', 'abstract', 'model', 'cost', 'maximum', 'price', 'may', 'charged', 'donor', 'operator', 'recipient', 'operator', 'set', 'cost', 'provided', 'price', 'fixed', 'basis', 'cost', 'way', 'consumer', 'dissuaded', 'making', 'use', 'facility', 'portability', 'article', 'directive', 'ec', 'european', 'parliament', 'council', 'march', 'common', 'regulatory', 'framework', 'electronic', 'communication', 'network', 'service', 'framework', 'directive', 'must', 'interpreted', 'meaning']...
# After preprocessing: 440 documents
# Sample preprocessed document: ['pricing', 'interconnection', 'related', 'provision', 'number', 'portability', 'referred', 'article', 'directive', 'ec']...
# Added bigrams. Sample document: ['pricing', 'interconnection', 'related', 'provision', 'number', 'portability', 'referred', 'article', 'directive', 'ec', 'european', 'parliament', 'council', 'march', 'universal']...
# Filtered documents using TF-IDF. Sample filtered document: ['pricing', 'interconnection', 'related', 'number', 'portability', 'concern', 'traffic', 'number', 'ported', 'set']...
# 2024-08-06 18:19:29,365 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2024-08-06 18:19:29,376 : INFO : built Dictionary<3416 unique tokens: ['abstract', 'adoption', 'advance', 'appeal', 'body']...> from 440 documents (total 19243 corpus positions)
# 2024-08-06 18:19:29,376 : INFO : Dictionary lifecycle event {'msg': "built Dictionary<3416 unique tokens: ['abstract', 'adoption', 'advance', 'appeal', 'body']...> from 440 documents (total 19243 corpus positions)", 'datetime': '2024-08-06T18:19:29.376567', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# 2024-08-06 18:19:29,377 : INFO : discarding 1581 tokens: [('abstract', 1), ('confidential', 1), ('confidentiality', 1), ('dissuaded', 1), ('donor', 1), ('ported', 1), ('porting', 1), ('reaching', 1), ('becomes', 1), ('referral', 1)]...
# 2024-08-06 18:19:29,377 : INFO : keeping 1835 tokens which were in no less than 2 and no more than 396 (=90.0%) documents
# 2024-08-06 18:19:29,379 : INFO : resulting dictionary: Dictionary<1835 unique tokens: ['adoption', 'advance', 'appeal', 'body', 'calculating']...>
# 2024-08-06 18:19:29,574 : INFO : using autotuned alpha, starting with [0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335]
# 2024-08-06 18:19:29,575 : INFO : using serial LDA version on this node
# 2024-08-06 18:19:29,578 : INFO : running online (multi-pass) LDA training, 30 topics, 10 passes over the supplied corpus of 440 documents, updating model once every 440 documents, evaluating perplexity every 0 documents, iterating 400x with a convergence threshold of 0.001000
# 2024-08-06 18:19:29,578 : INFO : PROGRESS: pass 0, at document #440/440
# 2024-08-06 18:19:29,758 : INFO : optimized alpha [0.030627225, 0.029947909, 0.02984939, 0.029961368, 0.030363228, 0.029597072, 0.029681822, 0.029346522, 0.030105766, 0.030803805, 0.029681742, 0.029513815, 0.030280912, 0.030098602, 0.029941203, 0.030278936, 0.030385798, 0.030191338, 0.0307844, 0.030014068, 0.029687928, 0.029932842, 0.030600721, 0.030880835, 0.030021422, 0.029850071, 0.0306299, 0.03037753, 0.030620502, 0.029598342]
# 2024-08-06 18:19:29,763 : INFO : topic #7 (0.029): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# 2024-08-06 18:19:29,764 : INFO : topic #11 (0.030): 0.021*"wine" + 0.019*"notification" + 0.013*"control" + 0.013*"set" + 0.013*"substance" + 0.013*"annex" + 0.011*"lawyer" + 0.011*"classification" + 0.008*"operator" + 0.008*"ruling"
# 2024-08-06 18:19:29,764 : INFO : topic #18 (0.031): 0.032*"trade_mark" + 0.016*"proprietor" + 0.014*"operator" + 0.007*"labelling_presentation" + 0.007*"online" + 0.006*"reasonably" + 0.006*"offer" + 0.006*"reference" + 0.006*"imported" + 0.006*"medical"
# 2024-08-06 18:19:29,764 : INFO : topic #9 (0.031): 0.012*"country" + 0.010*"device" + 0.009*"beer" + 0.009*"read_conjunction" + 0.008*"conjunction" + 0.007*"nature" + 0.007*"finding" + 0.007*"prohibition" + 0.006*"vehicle" + 0.006*"offer"
# 2024-08-06 18:19:29,764 : INFO : topic #23 (0.031): 0.014*"currency" + 0.011*"foreign" + 0.007*"exchange" + 0.007*"second" + 0.006*"brought" + 0.006*"travel" + 0.006*"borrower" + 0.006*"advertisement" + 0.006*"intelligible" + 0.006*"provide"
# 2024-08-06 18:19:29,765 : INFO : topic diff=23.379566, rho=1.000000
# 2024-08-06 18:19:29,767 : INFO : PROGRESS: pass 1, at document #440/440
# Dictionary size: 1835 (reduced from 3416)
# Corpus size: 440
# Sample corpus entry: [(0, 1), (1, 1), (2, 3), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1), (9, 1)]
# Training LDA model with num_topics=30, chunksize=2000, passes=10, iterations=400, alpha=auto, eta=auto
# 2024-08-06 18:19:29,804 : INFO : optimized alpha [0.02937443, 0.028386412, 0.028165247, 0.028358344, 0.029134613, 0.028022382, 0.02801169, 0.027512934, 0.028642654, 0.029534196, 0.02818097, 0.027826682, 0.028844334, 0.028637776, 0.028375862, 0.02875994, 0.028816748, 0.028932728, 0.029548159, 0.028515493, 0.028108556, 0.0282774, 0.02942291, 0.029997833, 0.02839255, 0.028161807, 0.029253058, 0.029024916, 0.02932307, 0.027899768]
# 2024-08-06 18:19:29,806 : INFO : topic #7 (0.028): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# 2024-08-06 18:19:29,807 : INFO : topic #11 (0.028): 0.020*"wine" + 0.018*"notification" + 0.017*"substance" + 0.013*"classification" + 0.013*"control" + 0.013*"set" + 0.013*"annex" + 0.010*"adaptation" + 0.010*"progress" + 0.010*"technical"
# 2024-08-06 18:19:29,807 : INFO : topic #9 (0.030): 0.013*"country" + 0.010*"beer" + 0.009*"read_conjunction" + 0.009*"device" + 0.009*"conjunction" + 0.008*"prohibition" + 0.008*"finding" + 0.007*"nature" + 0.007*"offer" + 0.007*"lawfully"
# 2024-08-06 18:19:29,808 : INFO : topic #18 (0.030): 0.039*"trade_mark" + 0.018*"proprietor" + 0.015*"operator" + 0.007*"online" + 0.007*"denmark" + 0.007*"reasonably" + 0.007*"bear" + 0.007*"labelling_presentation" + 0.006*"offer" + 0.006*"kingdom_denmark"
# 2024-08-06 18:19:29,808 : INFO : topic #23 (0.030): 0.016*"currency" + 0.012*"foreign" + 0.008*"exchange" + 0.007*"intelligible" + 0.007*"second" + 0.006*"provide" + 0.006*"repayment" + 0.006*"borrower" + 0.006*"existence" + 0.006*"brought"
# 2024-08-06 18:19:29,809 : INFO : topic diff=0.104720, rho=0.577350
# 2024-08-06 18:19:29,811 : INFO : PROGRESS: pass 2, at document #440/440
# 2024-08-06 18:19:29,846 : INFO : optimized alpha [0.028336566, 0.027128778, 0.026854295, 0.027104564, 0.028187424, 0.026791615, 0.026710201, 0.026098302, 0.027421592, 0.028550968, 0.02700323, 0.026547004, 0.027710546, 0.027521357, 0.027149804, 0.027565727, 0.027551435, 0.02799913, 0.02862882, 0.027439117, 0.026905458, 0.026987536, 0.028512554, 0.029274993, 0.027120506, 0.026813835, 0.028161488, 0.027950633, 0.028252957, 0.02657948]
# 2024-08-06 18:19:29,849 : INFO : topic #7 (0.026): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# 2024-08-06 18:19:29,849 : INFO : topic #29 (0.027): 0.018*"property" + 0.012*"data" + 0.009*"immovable_property" + 0.009*"present" + 0.009*"electronic_commerce" + 0.009*"processing" + 0.009*"intended" + 0.009*"determine" + 0.009*"course" + 0.009*"commerce"
# 2024-08-06 18:19:29,849 : INFO : topic #22 (0.029): 0.019*"kingdom_spain" + 0.019*"spain" + 0.015*"directory" + 0.013*"data" + 0.010*"adopt" + 0.010*"premise" + 0.009*"subscriber" + 0.009*"whose" + 0.009*"provider" + 0.009*"necessary_comply"
# 2024-08-06 18:19:29,850 : INFO : topic #18 (0.029): 0.043*"trade_mark" + 0.020*"proprietor" + 0.015*"operator" + 0.008*"online" + 0.007*"denmark" + 0.007*"bear" + 0.007*"reasonably" + 0.007*"offer" + 0.007*"labelling_presentation" + 0.007*"internet"
# 2024-08-06 18:19:29,850 : INFO : topic #23 (0.029): 0.017*"currency" + 0.014*"foreign" + 0.009*"exchange" + 0.008*"intelligible" + 0.007*"repayment" + 0.007*"second" + 0.007*"provide" + 0.007*"hellenic" + 0.007*"hellenic_republic" + 0.007*"reasonably"
# 2024-08-06 18:19:29,851 : INFO : topic diff=0.102410, rho=0.500000
# 2024-08-06 18:19:29,853 : INFO : PROGRESS: pass 3, at document #440/440
# 2024-08-06 18:19:29,887 : INFO : optimized alpha [0.02747023, 0.026095461, 0.025780778, 0.026074018, 0.027480718, 0.025780037, 0.025699854, 0.024947708, 0.026415888, 0.027727652, 0.026060691, 0.02549829, 0.026771668, 0.026625756, 0.02614075, 0.026579777, 0.026570594, 0.027275432, 0.02785609, 0.026545892, 0.025914388, 0.025930064, 0.027839405, 0.028719643, 0.02604895, 0.025712255, 0.02725444, 0.027057273, 0.027362153, 0.025499478]
# 2024-08-06 18:19:29,889 : INFO : topic #7 (0.025): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# 2024-08-06 18:19:29,890 : INFO : topic #29 (0.025): 0.018*"property" + 0.012*"data" + 0.009*"immovable_property" + 0.009*"electronic_commerce" + 0.009*"present" + 0.009*"processing" + 0.009*"intended" + 0.009*"determine" + 0.009*"course" + 0.009*"commerce"
# 2024-08-06 18:19:29,890 : INFO : topic #18 (0.028): 0.046*"trade_mark" + 0.022*"proprietor" + 0.016*"operator" + 0.008*"online" + 0.008*"denmark" + 0.008*"bear" + 0.007*"reputation" + 0.007*"internet" + 0.007*"offer" + 0.007*"reasonably"
# 2024-08-06 18:19:29,891 : INFO : topic #22 (0.028): 0.018*"kingdom_spain" + 0.018*"spain" + 0.015*"directory" + 0.013*"data" + 0.010*"premise" + 0.010*"adopt" + 0.010*"subscriber" + 0.009*"whose" + 0.009*"necessary_comply" + 0.009*"provider"
# 2024-08-06 18:19:29,891 : INFO : topic #23 (0.029): 0.018*"currency" + 0.014*"foreign" + 0.010*"exchange" + 0.009*"intelligible" + 0.008*"repayment" + 0.007*"reasonably" + 0.007*"provide" + 0.007*"hellenic" + 0.007*"hellenic_republic" + 0.007*"foreign_currency"
# 2024-08-06 18:19:29,892 : INFO : topic diff=0.100779, rho=0.447214
# 2024-08-06 18:19:29,894 : INFO : PROGRESS: pass 4, at document #440/440
# 2024-08-06 18:19:29,927 : INFO : optimized alpha [0.02672559, 0.025242614, 0.024872122, 0.02519906, 0.02686827, 0.024921048, 0.024842013, 0.023979155, 0.025560671, 0.02704504, 0.02528225, 0.024609901, 0.025969425, 0.025885414, 0.025283122, 0.025714006, 0.025736067, 0.02664647, 0.027186878, 0.02580657, 0.025071384, 0.025034, 0.027255822, 0.02823026, 0.025141777, 0.024831068, 0.026477344, 0.026266336, 0.02659881, 0.024586124]
# 2024-08-06 18:19:29,930 : INFO : topic #7 (0.024): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# 2024-08-06 18:19:29,930 : INFO : topic #29 (0.025): 0.018*"property" + 0.012*"data" + 0.009*"immovable_property" + 0.009*"electronic_commerce" + 0.009*"processing" + 0.009*"present" + 0.009*"intended" + 0.009*"determine" + 0.009*"course" + 0.009*"commerce"
# 2024-08-06 18:19:29,931 : INFO : topic #18 (0.027): 0.048*"trade_mark" + 0.023*"proprietor" + 0.016*"operator" + 0.009*"online" + 0.008*"denmark" + 0.008*"bear" + 0.007*"reputation" + 0.007*"internet" + 0.007*"entitled" + 0.007*"offer"
# 2024-08-06 18:19:29,932 : INFO : topic #22 (0.027): 0.018*"kingdom_spain" + 0.018*"spain" + 0.016*"directory" + 0.013*"data" + 0.011*"subscriber" + 0.011*"premise" + 0.010*"adopt" + 0.009*"whose" + 0.009*"necessary_comply" + 0.009*"provider"
# 2024-08-06 18:19:29,933 : INFO : topic #23 (0.028): 0.018*"currency" + 0.015*"foreign" + 0.010*"exchange" + 0.010*"intelligible" + 0.008*"repayment" + 0.008*"reasonably" + 0.008*"provide" + 0.008*"hellenic" + 0.008*"hellenic_republic" + 0.007*"foreign_currency"
# 2024-08-06 18:19:29,933 : INFO : topic diff=0.096961, rho=0.408248
# 2024-08-06 18:19:29,938 : INFO : PROGRESS: pass 5, at document #440/440
# 2024-08-06 18:19:29,980 : INFO : optimized alpha [0.026072493, 0.024501272, 0.024085287, 0.024439396, 0.026326835, 0.024175124, 0.024097173, 0.023144288, 0.024817226, 0.02644388, 0.024602717, 0.023840021, 0.025268966, 0.025260564, 0.024537856, 0.024961593, 0.025033008, 0.026137708, 0.026596535, 0.025159312, 0.024383072, 0.024278918, 0.026786394, 0.027790593, 0.024356073, 0.024067331, 0.025820248, 0.025598506, 0.025883086, 0.023795772]
# 2024-08-06 18:19:29,984 : INFO : topic #7 (0.023): 0.023*"charge" + 0.020*"authorisation" + 0.020*"licence" + 0.016*"equipment" + 0.013*"subscription" + 0.013*"mobile" + 0.013*"radio" + 0.010*"framework" + 0.010*"contains" + 0.010*"contact"
# ...
# 2024-08-06 18:20:17,482 : INFO : topic diff=0.023194, rho=0.218218
# 2024-08-06 18:20:17,515 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=1835, num_topics=90, decay=0.5, chunksize=2000> in 13.89s', 'datetime': '2024-08-06T18:20:17.515248', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'created'}
# 2024-08-06 18:20:17,525 : INFO : LdaState lifecycle event {'fname_or_handle': 'lda_models/topics_90_passes_20_iterations_400/trained_model.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-08-06T18:20:17.525308', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:20:17,528 : INFO : saved lda_models/topics_90_passes_20_iterations_400/trained_model.state
# 2024-08-06 18:20:17,530 : INFO : LdaModel lifecycle event {'fname_or_handle': 'lda_models/topics_90_passes_20_iterations_400/trained_model', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['dispatcher', 'id2word', 'state'], 'datetime': '2024-08-06T18:20:17.530771', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:20:17,534 : INFO : storing np array 'expElogbeta' to lda_models/topics_90_passes_20_iterations_400/trained_model.expElogbeta.npy
# 2024-08-06 18:20:17,545 : INFO : not storing attribute dispatcher
# 2024-08-06 18:20:17,548 : INFO : not storing attribute id2word
# 2024-08-06 18:20:17,550 : INFO : not storing attribute state
# 2024-08-06 18:20:17,553 : INFO : saved lda_models/topics_90_passes_20_iterations_400/trained_model
# 2024-08-06 18:20:17,554 : INFO : Dictionary lifecycle event {'fname_or_handle': 'lda_models/topics_90_passes_20_iterations_400/dictionary', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-08-06T18:20:17.554479', 'gensim': '4.3.2', 'python': '3.11.9 (main, Jul 16 2024, 11:07:54) [Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-12.5-arm64-arm-64bit', 'event': 'saving'}
# 2024-08-06 18:20:17,561 : INFO : saved lda_models/topics_90_passes_20_iterations_400/dictionary
# 2024-08-06 18:20:17,645 : INFO : topic #84 (0.008): 0.001*"judicial" + 0.001*"body" + 0.001*"following" + 0.001*"previously" + 0.001*"serious" + 0.001*"includes" + 0.001*"place" + 0.001*"position" + 0.001*"subsequent" + 0.001*"selection"
# 2024-08-06 18:20:17,655 : INFO : topic #86 (0.009): 0.048*"element" + 0.039*"finding" + 0.027*"annulment" + 0.024*"consequence" + 0.020*"amendment" + 0.020*"restoration" + 0.020*"objective" + 0.020*"removing" + 0.020*"lead" + 0.020*"altering"
# 2024-08-06 18:20:17,655 : INFO : topic #48 (0.009): 0.042*"ceiling" + 0.042*"instrument" + 0.021*"exceed" + 0.021*"set" + 0.021*"signed" + 0.021*"civil" + 0.021*"convention" + 0.021*"behalf" + 0.021*"transposing" + 0.021*"determined"
# 2024-08-06 18:20:17,658 : INFO : topic #11 (0.009): 0.068*"extension" + 0.045*"creditor" + 0.045*"concept" + 0.045*"sixth_chamber" + 0.045*"sixth" + 0.023*"precise" + 0.023*"contained" + 0.023*"form" + 0.023*"possible" + 0.023*"duration"
# 2024-08-06 18:20:17,661 : INFO : topic #63 (0.009): 0.031*"sum" + 0.031*"repayment" + 0.031*"spanish" + 0.015*"full" + 0.015*"temporal" + 0.015*"judicial" + 0.015*"hearing" + 0.015*"paid" + 0.015*"challenge" + 0.015*"procedure"
# 2024-08-06 18:20:17,661 : INFO : topic #19 (0.009): 0.044*"hand" + 0.044*"subparagraph" + 0.032*"framework" + 0.032*"renewal" + 0.032*"regulatory" + 0.032*"offer" + 0.032*"operator" + 0.032*"telephony" + 0.029*"two" + 0.026*"le"
# 2024-08-06 18:20:17,662 : INFO : topic #12 (0.009): 0.053*"substance" + 0.033*"packaging" + 0.033*"progress" + 0.033*"technical" + 0.033*"classification" + 0.033*"adaptation" + 0.026*"category" + 0.026*"august" + 0.020*"dangerous" + 0.013*"objectively"
# 2024-08-06 18:20:17,663 : INFO : topic #58 (0.009): 0.062*"natural" + 0.044*"water" + 0.027*"providing" + 0.027*"need" + 0.027*"mineral" + 0.027*"natural_mineral" + 0.027*"drawn" + 0.027*"conjunction" + 0.018*"read_conjunction" + 0.018*"date"
# 2024-08-06 18:20:17,663 : INFO : topic #7 (0.009): 0.030*"website" + 0.030*"provider" + 0.030*"change" + 0.030*"instrument" + 0.030*"accompanied" + 0.030*"unless" + 0.015*"met" + 0.015*"well" + 0.015*"behaviour" + 0.015*"framework"
# 2024-08-06 18:20:17,664 : INFO : topic #73 (0.009): 0.033*"mortgage" + 0.033*"mortgage_enforcement" + 0.033*"prohibits" + 0.033*"existence" + 0.033*"includes" + 0.017*"calculated" + 0.017*"nature" + 0.017*"request" + 0.017*"code" + 0.017*"confer"
# 2024-08-06 18:20:17,664 : INFO : topic #79 (0.009): 0.022*"evocation" + 0.019*"reasonably" + 0.015*"body" + 0.012*"element" + 0.012*"whose" + 0.012*"individual" + 0.010*"informed" + 0.010*"ass" + 0.010*"image" + 0.010*"similar"
# 2024-08-06 18:20:17,665 : INFO : topic #51 (0.010): 0.043*"tobacco" + 0.033*"finland" + 0.029*"advertisement" + 0.024*"manufacture" + 0.022*"kind" + 0.019*"disclosed_factor" + 0.019*"affect" + 0.019*"kind_affect" + 0.019*"validity" + 0.019*"factor"
# 2024-08-06 18:20:17,665 : INFO : topic #22 (0.010): 0.028*"currency" + 0.014*"unfairness" + 0.014*"kg" + 0.014*"mg" + 0.011*"data" + 0.011*"exchange" + 0.011*"denominated" + 0.011*"foreign" + 0.011*"denominated_foreign" + 0.011*"scheme"
# 2024-08-06 18:20:17,666 : INFO : topic #29 (0.010): 0.035*"latter" + 0.021*"new" + 0.021*"arbitration" + 0.021*"single" + 0.015*"even_though" + 0.015*"though" + 0.015*"event" + 0.014*"context" + 0.014*"draw" + 0.014*"design"
# 2024-08-06 18:20:17,666 : INFO : topic #18 (0.010): 0.060*"denmark" + 0.052*"kingdom_denmark" + 0.039*"bear" + 0.030*"make" + 0.023*"telephone" + 0.023*"july_approximation" + 0.023*"liability_defective" + 0.023*"hellenic_republic" + 0.023*"hellenic" + 0.015*"manufacturer"
# 2024-08-06 18:20:17,666 : INFO : topic #33 (0.010): 0.088*"germany" + 0.080*"federal_republic" + 0.080*"federal" + 0.032*"pre" + 0.032*"conduct" + 0.025*"framework" + 0.024*"offer" + 0.024*"point" + 0.024*"annex" + 0.024*"telecommunication"
# 2024-08-06 18:20:17,667 : INFO : topic #32 (0.010): 0.044*"electronic_commerce" + 0.042*"commerce" + 0.042*"information_society" + 0.042*"society" + 0.031*"tfeu" + 0.024*"aspect" + 0.024*"notification" + 0.017*"defendant" + 0.017*"whose" + 0.014*"annex"
# 2024-08-06 18:20:17,667 : INFO : topic #74 (0.010): 0.046*"grand" + 0.042*"duchy" + 0.042*"grand_duchy" + 0.042*"luxembourg" + 0.023*"prescribed" + 0.019*"necessary_comply" + 0.019*"premise" + 0.018*"adopt" + 0.017*"designation_origin" + 0.014*"thereof"
# 2024-08-06 18:20:17,668 : INFO : topic #62 (0.010): 0.137*"spain" + 0.115*"kingdom_spain" + 0.068*"adopt" + 0.058*"financial" + 0.055*"necessary_comply" + 0.053*"distance" + 0.036*"marketing" + 0.030*"september" + 0.029*"charge" + 0.014*"private"
# 2024-08-06 18:20:17,668 : INFO : topic #14 (0.010): 0.126*"belgium" + 0.118*"kingdom_belgium" + 0.042*"ruling" + 0.033*"preliminary" + 0.033*"preliminary_ruling" + 0.029*"certain_aspect" + 0.029*"aspect" + 0.025*"associated_guarantee" + 0.025*"guarantee" + 0.025*"associated"
# LDA model trained successfully
# Model saved to lda_models/topics_90_passes_20_iterations_400/trained_model
# Dictionary saved to lda_models/topics_90_passes_20_iterations_400/dictionary
# Corpus saved to lda_models/topics_90_passes_20_iterations_400/corpus
# Number of unique tokens: 1835
# Number of documents: 440
# Average topic coherence: -8.1622.
#
# Top topics:
# [(84,
#   '0.001*"judicial" + 0.001*"body" + 0.001*"following" + 0.001*"previously" + '
#   '0.001*"serious" + 0.001*"includes" + 0.001*"place" + 0.001*"position" + '
#   '0.001*"subsequent" + 0.001*"selection"'),
#  (86,
#   '0.048*"element" + 0.039*"finding" + 0.027*"annulment" + 0.024*"consequence" '
#   '+ 0.020*"amendment" + 0.020*"restoration" + 0.020*"objective" + '
#   '0.020*"removing" + 0.020*"lead" + 0.020*"altering"'),
#  (48,
#   '0.042*"ceiling" + 0.042*"instrument" + 0.021*"exceed" + 0.021*"set" + '
#   '0.021*"signed" + 0.021*"civil" + 0.021*"convention" + 0.021*"behalf" + '
#   '0.021*"transposing" + 0.021*"determined"'),
#  (11,
#   '0.068*"extension" + 0.045*"creditor" + 0.045*"concept" + '
#   '0.045*"sixth_chamber" + 0.045*"sixth" + 0.023*"precise" + 0.023*"contained" '
#   '+ 0.023*"form" + 0.023*"possible" + 0.023*"duration"'),
#  (63,
#   '0.031*"sum" + 0.031*"repayment" + 0.031*"spanish" + 0.015*"full" + '
#   '0.015*"temporal" + 0.015*"judicial" + 0.015*"hearing" + 0.015*"paid" + '
#   '0.015*"challenge" + 0.015*"procedure"'),
#  (19,
#   '0.044*"hand" + 0.044*"subparagraph" + 0.032*"framework" + 0.032*"renewal" + '
#   '0.032*"regulatory" + 0.032*"offer" + 0.032*"operator" + 0.032*"telephony" + '
#   '0.029*"two" + 0.026*"le"'),
#  (12,
#   '0.053*"substance" + 0.033*"packaging" + 0.033*"progress" + '
#   '0.033*"technical" + 0.033*"classification" + 0.033*"adaptation" + '
#   '0.026*"category" + 0.026*"august" + 0.020*"dangerous" + '
#   '0.013*"objectively"'),
#  (58,
#   '0.062*"natural" + 0.044*"water" + 0.027*"providing" + 0.027*"need" + '
#   '0.027*"mineral" + 0.027*"natural_mineral" + 0.027*"drawn" + '
#   '0.027*"conjunction" + 0.018*"read_conjunction" + 0.018*"date"'),
#  (7,
#   '0.030*"website" + 0.030*"provider" + 0.030*"change" + 0.030*"instrument" + '
#   '0.030*"accompanied" + 0.030*"unless" + 0.015*"met" + 0.015*"well" + '
#   '0.015*"behaviour" + 0.015*"framework"'),
#  (73,
#   '0.033*"mortgage" + 0.033*"mortgage_enforcement" + 0.033*"prohibits" + '
#   '0.033*"existence" + 0.033*"includes" + 0.017*"calculated" + 0.017*"nature" '
#   '+ 0.017*"request" + 0.017*"code" + 0.017*"confer"'),
#  (79,
#   '0.022*"evocation" + 0.019*"reasonably" + 0.015*"body" + 0.012*"element" + '
#   '0.012*"whose" + 0.012*"individual" + 0.010*"informed" + 0.010*"ass" + '
#   '0.010*"image" + 0.010*"similar"'),
#  (51,
#   '0.043*"tobacco" + 0.033*"finland" + 0.029*"advertisement" + '
#   '0.024*"manufacture" + 0.022*"kind" + 0.019*"disclosed_factor" + '
#   '0.019*"affect" + 0.019*"kind_affect" + 0.019*"validity" + 0.019*"factor"'),
#  (22,
#   '0.028*"currency" + 0.014*"unfairness" + 0.014*"kg" + 0.014*"mg" + '
#   '0.011*"data" + 0.011*"exchange" + 0.011*"denominated" + 0.011*"foreign" + '
#   '0.011*"denominated_foreign" + 0.011*"scheme"'),
#  (29,
#   '0.035*"latter" + 0.021*"new" + 0.021*"arbitration" + 0.021*"single" + '
#   '0.015*"even_though" + 0.015*"though" + 0.015*"event" + 0.014*"context" + '
#   '0.014*"draw" + 0.014*"design"'),
#  (18,
#   '0.060*"denmark" + 0.052*"kingdom_denmark" + 0.039*"bear" + 0.030*"make" + '
#   '0.023*"telephone" + 0.023*"july_approximation" + '
#   '0.023*"liability_defective" + 0.023*"hellenic_republic" + 0.023*"hellenic" '
#   '+ 0.015*"manufacturer"'),
#  (33,
#   '0.088*"germany" + 0.080*"federal_republic" + 0.080*"federal" + 0.032*"pre" '
#   '+ 0.032*"conduct" + 0.025*"framework" + 0.024*"offer" + 0.024*"point" + '
#   '0.024*"annex" + 0.024*"telecommunication"'),
#  (32,
#   '0.044*"electronic_commerce" + 0.042*"commerce" + '
#   '0.042*"information_society" + 0.042*"society" + 0.031*"tfeu" + '
#   '0.024*"aspect" + 0.024*"notification" + 0.017*"defendant" + 0.017*"whose" + '
#   '0.014*"annex"'),
#  (74,
#   '0.046*"grand" + 0.042*"duchy" + 0.042*"grand_duchy" + 0.042*"luxembourg" + '
#   '0.023*"prescribed" + 0.019*"necessary_comply" + 0.019*"premise" + '
#   '0.018*"adopt" + 0.017*"designation_origin" + 0.014*"thereof"'),
#  (62,
#   '0.137*"spain" + 0.115*"kingdom_spain" + 0.068*"adopt" + 0.058*"financial" + '
#   '0.055*"necessary_comply" + 0.053*"distance" + 0.036*"marketing" + '
#   '0.030*"september" + 0.029*"charge" + 0.014*"private"'),
#  (14,
#   '0.126*"belgium" + 0.118*"kingdom_belgium" + 0.042*"ruling" + '
#   '0.033*"preliminary" + 0.033*"preliminary_ruling" + 0.029*"certain_aspect" + '
#   '0.029*"aspect" + 0.025*"associated_guarantee" + 0.025*"guarantee" + '
#   '0.025*"associated"')]
# 2024-08-06 18:20:17,965 : INFO : -7.614 per-word bound, 195.8 perplexity estimate based on a held-out corpus of 440 documents with 16915 words
# Perplexity:  -7.613544123660979
# 2024-08-06 18:20:18,378 : INFO : -7.614 per-word bound, 195.8 perplexity estimate based on a held-out corpus of 440 documents with 16915 words
# 2024-08-06 18:20:18,422 : INFO : using ParallelWordOccurrenceAccumulator<processes=9, batch_size=64> to estimate probabilities from sliding windows
# 2024-08-06 18:20:20,828 : INFO : 9 accumulators retrieved from output queue
# 2024-08-06 18:20:21,116 : INFO : accumulated word occurrence stats for 1774 virtual documents
# Coherence Score:  0.4538564207186806
#
# Document 0 topics:
# [(69, 0.9868045)]
# Best topic: 69
# Top words in this topic:
# [('appeal', 0.039537888),
#  ('operator', 0.02376595),
#  ('number', 0.02376595),
#  ('examine', 0.023765948),
#  ('hearing', 0.023765946),
#  ('dispute', 0.015873138),
#  ('set', 0.015873138),
#  ('portability', 0.015873138),
#  ('body', 0.015873138),
#  ('regulatory', 0.015873138)]
# Original document: pricing interconnection related number portability concern traffic number ported set incurred mobile telephone operator implement request number porting adoption laying method used calculating fix advance abstract model maximum charged donor...
#
#
# Document 1 topics:
# [(87, 0.9696061)]
# Best topic: 87
# Top words in this topic:
# [('united', 0.04347172),
#  ('united_kingdom', 0.043471716),
#  ('milk', 0.037284274),
#  ('di', 0.037265968),
#  ('natural', 0.031074615),
#  ('natural_person', 0.031074615),
#  ('pdo', 0.0248791),
#  ('northern', 0.024871359),
#  ('ireland', 0.02365773),
#  ('system', 0.021143978)]
# Original document: natural becomes scheme implemented company allowing inter alia financial benefit connection purchase natural participating scheme referral company partner natural acting outside profession concept romanian natural_person inter_alia natural_person natural_person...
#
#
# Document 2 topics:
# [(1, 0.98864514)]
# Best topic: 1
# Top words in this topic:
# [('comparative', 0.033309206),
#  ('instrument', 0.020836266),
#  ('registered', 0.01675096),
#  ('system', 0.01667763),
#  ('sign', 0.01667763),
#  ('similar', 0.01667763),
#  ('bilateral', 0.01667763),
#  ('3a', 0.01667763),
#  ('trade_mark', 0.01667763),
#  ('advertisement', 0.01667763)]
# Original document: approximate 3a september misleading comparative proprietor registered entitled prevent third sign identical similar comparative advertisement satisfies 3a comparative permitted however required prevent sign identical similar registered met comparative advertisement sign...
#
#
# Document 3 topics:
# [(66, 0.9870189)]
# Best topic: 66
# Top words in this topic:
# [('advertiser', 0.025384987),
#  ('comparative', 0.020313602),
#  ('comparison', 0.020313602),
#  ('advertisement', 0.020313602),
#  ('3a', 0.020313596),
#  ('competitor', 0.017777905),
#  ('level', 0.015242209),
#  ('comparative_advertising', 0.012706514),
#  ('chain', 0.0127065135),
#  ('selection', 0.0127065135)]
# Original document: lay method calculating maximum charged calculation method allows bear proportion exercise activity mean maximum contrary harmonised set maximum upper limit provides payable exceeding upper limit total excluded impose repayment principal...
#
#
# Document 4 topics:
# [(35, 0.37257272), (47, 0.5994653)]
# Best topic: 47
# Top words in this topic:
# [('trade_mark', 0.03811636),
#  ('conformity', 0.036122262),
#  ('operator', 0.022075916),
#  ('online', 0.017101219),
#  ('lack', 0.016065402),
#  ('lack_conformity', 0.016065402),
#  ('proprietor', 0.016060991),
#  ('offer', 0.011870842),
#  ('place', 0.010050331),
#  ('required', 0.010050329)]
# Original document: allows recovery debt based potentially extrajudicial charge immovable property security far make excessively difficult impossible protect conferred determine included outside reflects content mandatory statutory regulatory determine immovable_property excessively_difficult...
#
# Low frequency words saved to csv_output/low_freq_words.csv
# High frequency words saved to csv_output/high_freq_words.csv
